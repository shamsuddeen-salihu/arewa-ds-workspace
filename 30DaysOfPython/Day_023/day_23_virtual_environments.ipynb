# %% [markdown]
# Windows PowerShell
# Copyright (C) 2015 Microsoft Corporation. All rights reserved.
#
# PS C:\Users\PC\projects\arewa-ds-workspace> pip install virtualenv
# Collecting virtualenv
#   Downloading https://files.pythonhosted.org/packages/83/22/54b1180756d2d6194bcafb7425d437c3034c4bff92129c3e1e633079e2c4/virtualenv-20.25.0-p
# y3-none-any.whl (3.8MB)
#     100% |████████████████████████████████| 3.8MB 1.3MB/s
# Collecting platformdirs<5,>=3.9.1 (from virtualenv)
#   Downloading https://files.pythonhosted.org/packages/31/16/70be3b725073035aa5fc3229321d06e22e73e3e09f6af78dcfdf16c7636c/platformdirs-4.0.0-p
# y3-none-any.whl
# Collecting importlib-metadata>=6.6; python_version < "3.8" (from virtualenv)
#   Downloading https://files.pythonhosted.org/packages/ff/94/64287b38c7de4c90683630338cf28f129decbba0a44f0c6db35a873c73c4/importlib_metadata-6
# .7.0-py3-none-any.whl
# Collecting filelock<4,>=3.12.2 (from virtualenv)
#   Downloading https://files.pythonhosted.org/packages/00/45/ec3407adf6f6b5bf867a4462b2b0af27597a26bd3cd6e2534cb6ab029938/filelock-3.12.2-py3-
# none-any.whl
# Collecting distlib<1,>=0.3.7 (from virtualenv)
#   Downloading https://files.pythonhosted.org/packages/8e/41/9307e4f5f9976bc8b7fea0b66367734e8faf3ec84bc0d412d8cfabbb66cd/distlib-0.3.8-py2.py
# 3-none-any.whl (468kB)
#     100% |████████████████████████████████| 471kB 1.4MB/s
# Collecting typing-extensions>=4.7.1; python_version < "3.8" (from platformdirs<5,>=3.9.1->virtualenv)
#   Downloading https://files.pythonhosted.org/packages/ec/6b/63cc3df74987c36fe26157ee12e09e8f9db4de771e0f3404263117e75b95/typing_extensions-4.
# 7.1-py3-none-any.whl
# Collecting zipp>=0.5 (from importlib-metadata>=6.6; python_version < "3.8"->virtualenv)
#   Downloading https://files.pythonhosted.org/packages/5b/fa/c9e82bbe1af6266adf08afb563905eb87cab83fde00a0a08963510621047/zipp-3.15.0-py3-none
# -any.whl
# Installing collected packages: typing-extensions, platformdirs, zipp, importlib-metadata, filelock, distlib, virtualenv
# Could not install packages due to an EnvironmentError: [Errno 13] Permission denied: 'c:\\program files (x86)\\python37-32\\Lib\\site-package
# s\\typing_extensions.py'
# Consider using the `--user` option or check the permissions.
#
# You are using pip version 10.0.1, however version 23.3.2 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.
# PS C:\Users\PC\projects\arewa-ds-workspace> pip install --user virtualenv
# Collecting virtualenv
#   Using cached https://files.pythonhosted.org/packages/83/22/54b1180756d2d6194bcafb7425d437c3034c4bff92129c3e1e633079e2c4/virtualenv-20.25.0-
# py3-none-any.whl
# Collecting platformdirs<5,>=3.9.1 (from virtualenv)
#   Using cached https://files.pythonhosted.org/packages/31/16/70be3b725073035aa5fc3229321d06e22e73e3e09f6af78dcfdf16c7636c/platformdirs-4.0.0-
# py3-none-any.whl
# Collecting distlib<1,>=0.3.7 (from virtualenv)
#   Using cached https://files.pythonhosted.org/packages/8e/41/9307e4f5f9976bc8b7fea0b66367734e8faf3ec84bc0d412d8cfabbb66cd/distlib-0.3.8-py2.p
# y3-none-any.whl
# Collecting filelock<4,>=3.12.2 (from virtualenv)
#   Using cached https://files.pythonhosted.org/packages/00/45/ec3407adf6f6b5bf867a4462b2b0af27597a26bd3cd6e2534cb6ab029938/filelock-3.12.2-py3
# -none-any.whl
# Collecting importlib-metadata>=6.6; python_version < "3.8" (from virtualenv)
#   Using cached https://files.pythonhosted.org/packages/ff/94/64287b38c7de4c90683630338cf28f129decbba0a44f0c6db35a873c73c4/importlib_metadata-
# 6.7.0-py3-none-any.whl
# Collecting typing-extensions>=4.7.1; python_version < "3.8" (from platformdirs<5,>=3.9.1->virtualenv)
#   Using cached https://files.pythonhosted.org/packages/ec/6b/63cc3df74987c36fe26157ee12e09e8f9db4de771e0f3404263117e75b95/typing_extensions-4
# .7.1-py3-none-any.whl
# Collecting zipp>=0.5 (from importlib-metadata>=6.6; python_version < "3.8"->virtualenv)
#   Using cached https://files.pythonhosted.org/packages/5b/fa/c9e82bbe1af6266adf08afb563905eb87cab83fde00a0a08963510621047/zipp-3.15.0-py3-non
# e-any.whl
# Installing collected packages: typing-extensions, platformdirs, distlib, filelock, zipp, importlib-metadata, virtualenv
#   The script virtualenv.exe is installed in 'C:\Users\PC\AppData\Roaming\Python\Python37\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Successfully installed distlib-0.3.8 filelock-3.12.2 importlib-metadata-6.7.0 platformdirs-4.0.0 typing-extensions-4.7.1 virtualenv-20.25.0 z
# ipp-3.15.0
# You are using pip version 10.0.1, however version 23.3.2 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.
# PS C:\Users\PC\projects\arewa-ds-workspace\30DaysOfPython> mkdir flask_project
#
#
#     Directory: C:\Users\PC\projects\arewa-ds-workspace\30DaysOfPython
#
#
# Mode                LastWriteTime         Length Name
# ----                -------------         ------ ----
# d-----       12/26/2023   1:38 PM                flask_project
#
#
# PS C:\Users\PC\projects\arewa-ds-workspace\30DaysOfPython> cd C:\Users\PC\projects\arewa-ds-workspace\30DaysOfPython\flask_project
# PS C:\Users\PC\projects\arewa-ds-workspace\30DaysOfPython\flask_project> python -m venv venv
# PS C:\Users\PC\projects\arewa-ds-workspace\30DaysOfPython\flask_project> ls venv
#
#
#     Directory: C:\Users\PC\projects\arewa-ds-workspace\30DaysOfPython\flask_project\venv
#
#
# Mode                LastWriteTime         Length Name
# ----                -------------         ------ ----
# d-----       12/26/2023   1:39 PM                Include
# d-----       12/26/2023   1:39 PM                Lib
# d-----       12/26/2023   1:40 PM                Scripts
# -a----       12/26/2023   1:39 PM             98 pyvenv.cfg
#
#
# PS C:\Users\PC\projects\arewa-ds-workspace\30DaysOfPython\flask_project> venv\Scripts\activate
# venv\Scripts\activate : File C:\Users\PC\projects\arewa-ds-workspace\30DaysOfPython\flask_project\venv\Scripts\Activate.ps1 cannot be
# loaded because running scripts is disabled on this system. For more information, see about_Execution_Policies at
# http://go.microsoft.com/fwlink/?LinkID=135170.
# At line:1 char:1
# + venv\Scripts\activate
# + ~~~~~~~~~~~~~~~~~~~~~
#     + CategoryInfo          : SecurityError: (:) [], PSSecurityException
#     + FullyQualifiedErrorId : UnauthorizedAccess
# PS C:\Users\PC\projects\arewa-ds-workspace\30DaysOfPython\flask_project> Set-ExecutionPolicy -ExecutionPolicy RemoteSigned -Scope CurrentUser
# PS C:\Users\PC\projects\arewa-ds-workspace\30DaysOfPython\flask_project> venv\Scripts\activate
# (venv) PS C:\Users\PC\projects\arewa-ds-workspace\30DaysOfPython\flask_project> pip freeze
# (venv) PS C:\Users\PC\projects\arewa-ds-workspace\30DaysOfPython\flask_project> pip install flask
# Collecting flask
#   Downloading https://files.pythonhosted.org/packages/9f/1a/8b6d48162861009d1e017a9740431c78d860809773b66cac220a11aa3310/Flask-2.2.5-py3-none
# -any.whl (101kB)
#     100% |████████████████████████████████| 102kB 75kB/s
# Collecting itsdangerous>=2.0 (from flask)
#   Downloading https://files.pythonhosted.org/packages/68/5f/447e04e828f47465eeab35b5d408b7ebaaaee207f48b7136c5a7267a30ae/itsdangerous-2.1.2-p
# y3-none-any.whl
# Collecting importlib-metadata>=3.6.0; python_version < "3.10" (from flask)
#   Using cached https://files.pythonhosted.org/packages/ff/94/64287b38c7de4c90683630338cf28f129decbba0a44f0c6db35a873c73c4/importlib_metadata-
# 6.7.0-py3-none-any.whl
# Collecting click>=8.0 (from flask)
#   Downloading https://files.pythonhosted.org/packages/00/2e/d53fa4befbf2cfa713304affc7ca780ce4fc1fd8710527771b58311a3229/click-8.1.7-py3-none
# -any.whl (97kB)
#     100% |████████████████████████████████| 102kB 144kB/s
# Collecting Werkzeug>=2.2.2 (from flask)
#   Downloading https://files.pythonhosted.org/packages/f6/f8/9da63c1617ae2a1dec2fbf6412f3a0cfe9d4ce029eccbda6e1e4258ca45f/Werkzeug-2.2.3-py3-n
# one-any.whl (233kB)
#     100% |████████████████████████████████| 235kB 151kB/s
# Collecting Jinja2>=3.0 (from flask)
#   Downloading https://files.pythonhosted.org/packages/bc/c3/f068337a370801f372f2f8f6bad74a5c140f6fda3d9de154052708dd3c65/Jinja2-3.1.2-py3-non
# e-any.whl (133kB)
#     100% |████████████████████████████████| 133kB 28kB/s
# Collecting typing-extensions>=3.6.4; python_version < "3.8" (from importlib-metadata>=3.6.0; python_version < "3.10"->flask)
#   Using cached https://files.pythonhosted.org/packages/ec/6b/63cc3df74987c36fe26157ee12e09e8f9db4de771e0f3404263117e75b95/typing_extensions-4
# .7.1-py3-none-any.whl
# Collecting zipp>=0.5 (from importlib-metadata>=3.6.0; python_version < "3.10"->flask)
#   Using cached https://files.pythonhosted.org/packages/5b/fa/c9e82bbe1af6266adf08afb563905eb87cab83fde00a0a08963510621047/zipp-3.15.0-py3-non
# e-any.whl
# Collecting colorama; platform_system == "Windows" (from click>=8.0->flask)
#   Downloading https://files.pythonhosted.org/packages/d1/d6/3965ed04c63042e047cb6a3e6ed1a63a35087b6a609aa3a15ed8ac56c221/colorama-0.4.6-py2.p
# y3-none-any.whl
# Collecting MarkupSafe>=2.1.1 (from Werkzeug>=2.2.2->flask)
#   Downloading https://files.pythonhosted.org/packages/b2/0d/cbaade3ee8efbd5ce2fb72b48cc51479ebf3d4ce2c54dcb6557d3ea6a950/MarkupSafe-2.1.3-cp3
# 7-cp37m-win32.whl
# Installing collected packages: itsdangerous, typing-extensions, zipp, importlib-metadata, colorama, click, MarkupSafe, Werkzeug, Jinja2, flas
# k
# Successfully installed Jinja2-3.1.2 MarkupSafe-2.1.3 Werkzeug-2.2.3 click-8.1.7 colorama-0.4.6 flask-2.2.5 importlib-metadata-6.7.0 itsdanger
# ous-2.1.2 typing-extensions-4.7.1 zipp-3.15.0
# You are using pip version 10.0.1, however version 23.3.2 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.
# (venv) PS C:\Users\PC\projects\arewa-ds-workspace\30DaysOfPython\flask_project> pip freeze
# click==8.1.7
# colorama==0.4.6
# Flask==2.2.5
# importlib-metadata==6.7.0
# itsdangerous==2.1.2
# Jinja2==3.1.2
# MarkupSafe==2.1.3
# typing-extensions==4.7.1
# Werkzeug==2.2.3
# zipp==3.15.0
# You are using pip version 10.0.1, however version 23.3.2 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.
# (venv) PS C:\Users\PC\projects\arewa-ds-workspace\30DaysOfPython\flask_project> deactivate
# PS C:\Users\PC\projects\arewa-ds-workspace\30DaysOfPython\flask_project>
